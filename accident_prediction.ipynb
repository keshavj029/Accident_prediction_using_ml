# %%
import pandas as pd
import numpy as np

# %%
accidents = pd.read_csv('US_Accidents_Dec21_updated.csv')

# %%
accidents.shape
# Out:
# (2845342, 47)

# %%
accidents.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
accidents.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  Number       Street  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...     NaN  Outerbelt E
# 1                 At OH-4/OH-235/Exit 41 - Accident.     NaN       I-70 E
# ...

# %%
accidents.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
accidents.isnull().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# ...

# %%
accidents = accidents.drop(['Street', 'County','State', 'Zipcode', 'Country', 'Airport_Code', 'Timezone', 'Side','City'], axis = 1)

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 38 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Weather_Timestamp      object
#  12  Temperature(F)         float64
#  13  Wind_Chill(F)          float64
#  14  Humidity(%)            float64
#  15  Pressure(in)           float64
#  16  Visibility(mi)         float64
#  17  Wind_Direction         object
#  18  Wind_Speed(mph)        float64
#  19  Precipitation(in)      float64
#  20  Weather_Condition      object
# ...

# %%
pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999
import matplotlib.pyplot as plt
import seaborn as sns

# %%
accidents.dropna(inplace = True)
print(accidents.shape)
# Out:
# (943319, 38)

# %%
for x in np.arange(1,5):
    plt.subplots(figsize=(20,5))
    accidents.loc[accidents["Severity"] == x]['Weather_Condition'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='y',edgecolor='y',align='center',linewidth=1)
    plt.xlabel('Weather Condition',fontsize=16)
    plt.ylabel('Accident Count',fontsize=16)
    plt.title('20 of The Main Weather Conditions for Accidents of Severity ' + str(x),fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
f,ax=plt.subplots(1,2,figsize=(25,8))
accidents['Severity'].value_counts().plot.pie(explode=[0.1,0.1,0.1,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Percentage Severity Distribution')
ax[0].set_ylabel('Count')
sns.countplot('Severity',data=accidents,ax=ax[1],order=accidents['Severity'].value_counts().index)
ax[1].set_title('Count of Severity')
plt.show()
# Out:
# C:\Users\kesha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
accidents.drop(columns = ['ID'], inplace = True)
accidents.drop(columns = ['Description'], inplace = True)

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 943319 entries, 42 to 2845307
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Severity               943319 non-null  int64
#  1   Start_Time             943319 non-null  object
#  2   End_Time               943319 non-null  object
#  3   Start_Lat              943319 non-null  float64
#  4   Start_Lng              943319 non-null  float64
#  5   End_Lat                943319 non-null  float64
#  6   End_Lng                943319 non-null  float64
#  7   Distance(mi)           943319 non-null  float64
#  8   Number                 943319 non-null  float64
#  9   Weather_Timestamp      943319 non-null  object
#  10  Temperature(F)         943319 non-null  float64
#  11  Wind_Chill(F)          943319 non-null  float64
#  12  Humidity(%)            943319 non-null  float64
#  13  Pressure(in)           943319 non-null  float64
# ...

# %%
categorical_columns = accidents.select_dtypes(include=['object','bool']).columns
categorical_columns
# Out:
# Index(['Start_Time', 'End_Time', 'Weather_Timestamp', 'Wind_Direction',
#        'Weather_Condition', 'Amenity', 'Bump', 'Crossing', 'Give_Way',
#        'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop',
#        'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset',
#        'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %%
from sklearn import preprocessing

for i in categorical_columns:
    en = preprocessing.LabelEncoder()
    accidents[i]= en.fit_transform(accidents[i])

# %%
accidents.head(3)
# Out:
#     Severity  Start_Time  End_Time  Start_Lat  Start_Lng   End_Lat   End_Lng  \
# 42         4           0         0   40.45112  -85.15048  40.35429 -85.14993
# 43         4           0         0   40.35429  -85.14993  40.45112 -85.15048
# 47         4           1         1   40.72813  -84.78965  40.74559 -84.78962
#
#     Distance(mi)   Number  Weather_Timestamp  Temperature(F)  Wind_Chill(F)  \
# 42         6.690   9001.0                  0            19.9            7.3
# 43         6.690    473.0                  0            19.9            7.3
# 47         1.206  12998.0                  1            17.1            0.6
#
#     Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Direction  \
# 42         81.0         29.85             2.0              20
# 43         81.0         29.85             2.0              20
# 47         77.0         29.91             2.5              22
#
#     Wind_Speed(mph)  Precipitation(in)  Weather_Condition  Amenity  Bump  \
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 943319 entries, 42 to 2845307
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Severity               943319 non-null  int64
#  1   Start_Time             943319 non-null  int32
#  2   End_Time               943319 non-null  int32
#  3   Start_Lat              943319 non-null  float64
#  4   Start_Lng              943319 non-null  float64
#  5   End_Lat                943319 non-null  float64
#  6   End_Lng                943319 non-null  float64
#  7   Distance(mi)           943319 non-null  float64
#  8   Number                 943319 non-null  float64
#  9   Weather_Timestamp      943319 non-null  int32
#  10  Temperature(F)         943319 non-null  float64
#  11  Wind_Chill(F)          943319 non-null  float64
#  12  Humidity(%)            943319 non-null  float64
#  13  Pressure(in)           943319 non-null  float64
# ...

# %%
train_y = accidents['Severity'].values
x_cols = [col for col in accidents.columns if col not in ['Severity'] if accidents[col].dtype=='float64'or accidents[col].dtype=='int64']
train_col= accidents[x_cols]

fearture_name = train_col.columns.values 

from sklearn import ensemble 

model = ensemble.ExtraTreesRegressor(n_estimators=25, max_depth=30, max_features=0.3, n_jobs=-1, random_state=0)
model.fit(train_col,train_y)


importance = model.feature_importances_
std = np.std([tree.feature_importances_ for tree in model.estimators_],axis=0)
indices = np.argsort(importance)[::-1][:20]

plt.figure(figsize=(20,7))
plt.title("Feature importances")
plt.bar(range(len(indices)), importance[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(len(indices)), fearture_name[indices], rotation='vertical')
plt.xlim([-1, len(indices)])
plt.show()

# %%
y = accidents['Severity'].copy()
X = accidents.drop('Severity', axis=1).copy()

# %%
y.unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
y = y-1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=100)

# %%
X_train.shape
# Out:
# (660323, 35)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True)
classifier_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
classifier_rf.oob_score_
# Out:
# 0.9473091199307005

# %%
y_pred_test = classifier_rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test, y_pred_test)
# Out:
# 0.9473773480897256
